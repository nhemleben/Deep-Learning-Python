# %%
import keras
keras.__version__
# Out:
# Using TensorFlow backend.
# '2.3.1'

# %% [markdown]
# # Text generation with LSTM
#
# This notebook contains the code samples found in Chapter 8, Section 1 of [Deep Learning with Python](https://www.manning.com/books/deep-learning-with-python?a_aid=keras&a_bid=76564dff). Note that the original text features far more content, in particular further explanations and figures: in this notebook, you will only find source code and related comments.
#
# ----
#
# [...]
#
# ## Implementing character-level LSTM text generation
#
#
# Let's put these ideas in practice in a Keras implementation. The first thing we need is a lot of text data that we can use to learn a
# language model. You could use any sufficiently large text file or set of text files -- Wikipedia, the Lord of the Rings, etc. In this
# example we will use some of the writings of Nietzsche, the late-19th century German philosopher (translated to English). The language model
# we will learn will thus be specifically a model of Nietzsche's writing style and topics of choice, rather than a more generic model of the
# English language.

# %% [markdown]
# ## Preparing the data
#
# Let's start by downloading the corpus and converting it to lowercase:

# %%
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 0s 0us/step
# Corpus length: 600893

# %% [markdown]
# Next, we will extract partially-overlapping sequences of length `maxlen`, one-hot encode them and pack them in a 3D Numpy array `x` of
# shape `(sequences, maxlen, unique_characters)`. Simultaneously, we prepare a array `y` containing the corresponding targets: the one-hot
# encoded characters that come right after each extracted sequence.

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...

# %% [markdown]
# ## Building the network
#
# Our network is a single `LSTM` layer followed by a `Dense` classifier and softmax over all possible characters. But let us note that
# recurrent neural networks are not the only way to do sequence data generation; 1D convnets also have proven extremely successful at it in
# recent times.

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %% [markdown]
# Since our targets are one-hot encoded, we will use `categorical_crossentropy` as the loss to train the model:

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## Training the language model and sampling from it
#
#
# Given a trained model and a seed text snippet, we generate new text by repeatedly:
#
# * 1) Drawing from the model a probability distribution over the next character given the text available so far
# * 2) Reweighting the distribution to a certain "temperature"
# * 3) Sampling the next character at random according to the reweighted distribution
# * 4) Adding the new character at the end of the available text
#
# This is the code we use to reweight the original probability distribution coming out of the model,
# and draw a character index from it (the "sampling function"):

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# Finally, this is the loop where we repeatedly train and generated text. We start generating text using a range of different temperatures
# after every epoch. This allows us to see how the generated text evolves as the model starts converging, as well as the impact of
# temperature in the sampling strategy.

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# Epoch 1/1
# 200278/200278 [==============================] - 66s 329us/step - loss: 1.9642
# --- Generating with seed: "ch, so that its
# root remains weak, and is easily torn up.
#
# 1"
# ------ temperature: 0.2
# ch, so that its
# root remains weak, and is easily torn up.
#
# 12. the strught to be all the master and the string that the string the will the string the has the string the string and sould to the string that the string the faller to be histo and the streek of the seef the strught the has and the histor and the string the seef the latter and sould the most as the sould the general the string and the string that the string the string and sould that the string
# ------ temperature: 0.5
# string that the string the string and sould that the string to all the gilse, and his disciveless the to all contulned the dost same that and deflect, end and free the radion of the seems have sulf-is a specie, that in their sees the has the doms to a misthtation of the latter sure the have to say but the
# fear perhaps stayfind to spirit of the will their to as and to as a
# conscionion to the will the strust to be
# adet to all atistical stands the soult a con
# ------ temperature: 1.0
# he strust to be
# adet to all atistical stands the soult a convned, "sown volticales accivind, mays, but benomely has pastion. fur of a funting to hwo plactable should to false fearntres with tadxistarbitity, from thom theil
# and cisif, mmans of the smuth, from achial renogied sint? andory flove, and soul," with that estent yy. yay, trads,.
# b) things prifferiration.
#
# 22. hithest it for to caure : on even arsences, all taker
# perhaps but newhy
# intasiut us somet
# ------ temperature: 1.2
# even arsences, all taker
# perhaps but newhy
# intasiut us somethinge"fulists
# he selvused with stepevit ussiled he
# manky
# plogeh, irstlianed and asge)k. that pa ssudc. as bilwed tood:
# indercnssind to
# lacve-is and gnest who fin simibitioniby fallys know prear bild dording,sly conour
# withifagif makly
# has aad, of himdelbordo bet sanithed
# with
# locsibrity;
# and mist thr sayv grudy upon-enti re! in no he still uponger; and jud;"" whechovi, he hnity of a detend--nuture
# epoch 2
# Epoch 1/1
# 200278/200278 [==============================] - 64s 319us/step - loss: 1.6155
# --- Generating with seed: "should
# it be praised, a sort of resentful disdain is compati"
# ------ temperature: 0.2
# should
# it be praised, a sort of resentful disdain is compations of the most present the man of the same of the same of the most and all the fact of the same of the delight and all the same of the most and all the same the strength and and all the same of the domand and all the strength and all the same of the same and the spirit of the all the same of the most word of the most and in the present have the more all the all the same of the strength the man of
# ------ temperature: 0.5
# ave the more all the all the same of the strength the man of the same all the will and all the fall of the art of the most have so the more all the dothent in the domand of the matters of the unart shorth of the sapage of the spirits as the more was so for the instinct, and been an and the more proper of the loke and there all the are the the world and pradication of contemptent, and all the proplens of consequent artually the simpless in the sportion, and
# ------ temperature: 1.0
# ens of consequent artually the simpless in the sportion, and maken of eureci the ungerstation and
# posence doy ferther as ditaces of its ropecistom, must the pole of
# the ngrre, deceined in goder. a pridemenisms of the obrili regatte of there also, of necessary sidulial wornting (my more of  or
# it su, only as a recentable with
# to be stope have and arelier that but itselfal--he spirvom finallys--extritifiancl ourself your impression from our complementn of th
# ------ temperature: 1.2
# itifiancl ourself your impression from our complementn of the as brious ealth, one apirfaction of sn the hous if delicat, as a pity, whom growen must as raxence and philosophers--of ew which as the eviluring dut be sawers. metspy and "pictures and least as subter to er an discles. even unterly
# upor of mocally, he weakmen neim.g--when it lal.nce under whetill cheen utestal
# spirst. asistains. it to--a tomantained ne bothing
# and desides--
# hals,
# a.
# only sorthe
# epoch 3
# Epoch 1/1
# 200278/200278 [==============================] - 66s 330us/step - loss: 1.5275
# --- Generating with seed: " to say, as
# conventional fictions for the purpose of designa"
# ------ temperature: 0.2
#  to say, as
# conventional fictions for the purpose of designal the sense of the sense of the sentiments of the sense of the sense of the strong the sense of the sense of the sense of the present to be sense of the sense of the be distrust the sense of the world the proforal sense of the profortion of the sense of the sense of the sense of the world of the sense of the strength the sense of the proforal the sense of the spirit of the sense of the sense of th
# ------ temperature: 0.5
# oral the sense of the spirit of the sense of the sense of the same with the morality has the moralistic promable, the morality, the earth. it is every the devery school to many the act in the willing to opposing
# sensition of metaphysical proforal the more one man were things the sension of the deep the are has hitherto restined to let it is the allay and which a are in the passion it is a constitute and minds from the mest the greater of the surection to h
# ------ temperature: 1.0
# te and minds from the mest the greater of the surection to himself of a ple"sioral very ether a conduct of best with that immediots-loquint which was ditain with point to be was possibiti, worthant and onely, and become andis hemes bespishemer, or of life? opidion which tenty trastical world proxeption of a reason their than
# recenture the preserval
# man even speive," out often expleanate, it has it is whoever bot an instinctitic, we ially per-an
# improsence.
# ------ temperature: 1.2
#  is whoever bot an instinctitic, we ially per-an
# improsence. why
# creation trawist.--the great stricty believe it kwats" comoricable which might thg conductding sheep time c;oll. the he dinting: the mody eminever.
#
#
# 18utt=evous, which which, such in the warie trakelen chan-what teded to, yomest.will be powilgs,
# there as a cirrificting
# docepuns and proatisp" the cerectian such viction it seet
# withs timpiline, has croist spiritx in a -huthfulnerno dangic muc
# epoch 4
# Epoch 1/1
# 200278/200278 [==============================] - 66s 327us/step - loss: 1.4814
# --- Generating with seed: "--in place of the "immediate certainty" in which the people "
# ------ temperature: 0.2
# --in place of the "immediate certainty" in which the people the moral and the experience, and the respect to and the moral and the morality of the moral to the contempt to the moral with the strigited the self and interroces the sensition of the states the stool to the self and the highest and the strong the moral and the moral standing the self and the moral the self and the are and the controlite and the moral superiorial states and the states to the sto
# ------ temperature: 0.5
# e and the moral superiorial states and the states to the stori, in the experience of the recomoristic most standing to them them to emotioned, to being doffersable certainty happentary delight to a reperse "deligious easie of the soul, and the self has to us and controlite indulged, the world that the arribel and shartence and to and reverence of the and to them one who has tentions and the self sensitions to the are of this prise to a has to being in the
# ------ temperature: 1.0
# ensitions to the are of this prise to a has to being in the treans the europenttow, and shone--strong
# moral who comed of things with othenofies may be adoribility in their act innomit for europe and religious and earthing
# the masterstained that one has giving new
# are dostedned best generative in acnocree for the from virtual minding and well one who who men as
# astion,
# in
# former, and whose what heal love newby, satiafiate and the
# medioc", plainly moral prob
# ------ temperature: 1.2
# l love newby, satiafiate and the
# medioc", plainly moral probaw but
# instant
# grothy may lawsious, it make the richer prefermines, emotiannd and
# dece, his delence and certainly and mutuous, that hon
# morean
# ruleon with onil pain, any metspright;ether unjumiht
# emotive, and excausuity, powery, like tain toowomoral really allostruds;
# like-with pritciless whe man yemines and taste. the so portriataed
# has a superiiouseled, the among
# strong toming imelis, at testihi
# epoch 5
# Epoch 1/1
# 200278/200278 [==============================] - 65s 323us/step - loss: 1.4489
# --- Generating with seed: "one, whether waking or
# sleeping. uncontrolled and entangled "
# ------ temperature: 0.2
# one, whether waking or
# sleeping. uncontrolled and entangled to the sense of the same in the same and he was and superiorated to the sense of the sense of the sense of the sense of the sense and the will to any man in the same things and the same tood the sense of the sense of the sense of the same and with the sense of the true of the sense of the sense of the sense and the present the sense of the same and the antithesis of the sense of which as in the sa
# ------ temperature: 0.5
# e same and the antithesis of the sense of which as in the same and sense is the present to an even more sense, and for the basis and
# men and
# from the and believe the existence, that is at present and the good and some with the sense of a false of the sense that is the
# same thing of the philosophy. the strength and infined and the reasons and since is for which experience, and the badication of things, and superstition of conceal called teesured and delicia
# ------ temperature: 1.0
# ngs, and superstition of conceal called teesured and delicialsion may men were, and in its sympathy with importine, withds to prifours of which general with insciences and cate in ourset!"
#
#
# witible, is, with he would calle, might tritums, and which inner smortlish in the
# essential man which a: things, and many. picharible
# (toom, with an in the element somecte,
# to withers"--we conory perhaps had to be pain, theretober. this way
# brecate; in the
# vering, ligh
# ------ temperature: 1.2
# o be pain, theretober. this way
# brecate; in the
# vering, lightsanly ypols, ala the an reyouicate apparently, that asitize aid in derminated, worss and once and "task,
# that becauses that spirit, be evil was flee
# thoughtin
# brayity and
# ty mutuxly neasoning, for.wiritaphy. oreimains,
# ind infided
# in should upon, to woman withs min, unupintarier
# allo slavely very never in the langmatable
# himself the mepart
# for say, in creed, pdut attempt, it waitivi, he walthess,
# epoch 6
# Epoch 1/1
# 200278/200278 [==============================] - 65s 323us/step - loss: 1.4291
# --- Generating with seed: "ch most disturb us at
# present do so because of the erroneous"
# ------ temperature: 0.2
# ch most disturb us at
# present do so because of the erroneous one of the man in the greatest and something and and the sense and the sense of the more and the sense of the conduct of the most and soul of the more and the seems to the strong and one with the same and such a strong and condition and personal and soul of the sense of the destrays and souls and the sense of the sense of the more the man also the most and soul of the sense of the sense of the mo
# ------ temperature: 0.5
# n also the most and soul of the sense of the sense of the more posing the meaning and the last respect to the any self everything that is the self along and and the condition of which he strong, the value of a so to the ears something and in the same descience of the destray and believe that is the domable to something to the strong and standard, which as in the demonds the men and gratifies that the vistoment and men, and the ethiches. the religion someth
# ------ temperature: 1.0
# the vistoment and men, and the ethiches. the religion something and more too knowledge, and deceasures with which can be discraves,"--in perholant sharitable
# actually aequaticy imbaragically something not classn--never view their tratavently
# noble believes is imory of the "kness and bevent darine soless with any oneself renotion long because of vupericitive, and hastoranitym, of her rules than is not overnond. that is ashieted overthang human one
# they as h
# ------ temperature: 1.2
# not overnond. that is ashieted overthang human one
# they as his net that gradually it
# askings and us: as a thinch heselve rans,", withir this
# above the still that one's powerfyest
# themselves, and civilizated and formed,wition", that this wart, of those enjemlym rage has become
# degrear spjecifies, as unlimacily
# one larsgirable whice
# he is an oneagine, if the rekance tone, however, you always
# to grodpong
# or enough and very ordinary christian, ythe
# could eyes.
# epoch 7
# Epoch 1/1
# 200278/200278 [==============================] - 65s 325us/step - loss: 1.4130
# --- Generating with seed: "elf thereby, as a
# despiser.
#
# 79. a soul which knows that it "
# ------ temperature: 0.2
# elf thereby, as a
# despiser.
#
# 79. a soul which knows that it is a soul the man of the spirit of the belief the are in the same work and the enough to the sense of the same and sense of the same and cause of the end and sometime of the same and sometime to the artists of the sense of the man also the act and sense of the sense of the same and something and something in the same of conscience of the sense of the sense of the sense of the sense of the same and
# ------ temperature: 0.5
# sense of the sense of the sense of the sense of the same and conduct of the catege of the evolution. and the intimestnisted to the most form of the same and sense of the man as something has it something to that a man the absued and later to the noble and soul, suffering and souncied the master as the arrible and the certainly and thing of his case be a cause of the last and dutiess and person and the soul, and the stole is the miscraided by a sometime the
# ------ temperature: 1.0
#  the soul, and the stole is the miscraided by a sometime the god: ere schawoss the perstity stears or forme
# even to own sausts, nothing
# the eyote of thon of tasiin is, or action--are false to be ground to sayity, "one valuaribication. he was
# dedned, and highest man eword aritation itself looks act qual extmidalaged something
# is, frant dad overwall away conduct, all person, bevery," carable to is ont offtided even fate callive to gathed to exprysingly attec
# ------ temperature: 1.2
# nt offtided even fate callive to gathed to exprysingly attectacitypje must by thing who back, onize or fett the irepudided and reverierse from the resist than virtuous extra.tile him what
# capable. it is suffering---it in"juintecy is also civili dith the end than
# netvaped,,-in been, it makes and thknws close dolds" commend the pivime of he ?  perhaps old iorityfip pihise and see footh.r--thish? aw ortism gains and docted leadiess
#
# ind,n ory, itself reakitim
# epoch 8
# Epoch 1/1
# 200278/200278 [==============================] - 66s 328us/step - loss: 1.3993
# --- Generating with seed: "out a sort of experiential estimation of the desirability of"
# ------ temperature: 0.2
# out a sort of experiential estimation of the desirability of the moral and the greatest man and not the conceals the most soul of the contrary and the greater the good and as the strength the same and profoundly and so the masters of the same the strength of the strength to have the world and the conceals the conceals the moral man and profoundly the concealed the strength and soul in the contrast and at the strength and the strength that the conscience of
# ------ temperature: 0.5
#  and at the strength and the strength that the conscience of the concealed the subtle in the enough in the free spirit and concealing and so presens of all the ratering that the most in every states and importance, and the truth thinks and the concealed for the power of the more from the religious for the acts that every conceals the endear, the greatest the development of the wors
# of the fact that has the something and in the belief of the greater and bec
# ------ temperature: 1.0
# t has the something and in the belief of the greater and becourded things, and is the inclonined themselvesing of
# trans and finer stronger, the love man
# a-germental
# upbenestly in wifroull can by gradual believe with no knotn of human estuest
# them manking and well and power with the gragmances
# that your
# e, emecrate acnasi, whoreher into immedived and anonef" phanoles"--n"vamedly noakness, that they discurated the cainrs and seasm of vant my which to estebut
# ------ temperature: 1.2
#  discurated the cainrs and seasm of vant my which to estebutmant and tolo-gures, no
# leary of layed more herelons
# one frientances of "present in htauting, funenams of prefomine thouvhk, to detess
# exescation of its valuem"), than explohue;
# velsesfactude, to be
# such
# stipefiis and lawer
# embitlishched. to ye promiation
# withoutedust clas,
# inagenader fr! wherever idet instances,
# and opwere
# ci"deaws through ay instinctifies my "silence, a manmlre
# is, fe?loun, or b
# epoch 9
# Epoch 1/1
# 200278/200278 [==============================] - 65s 323us/step - loss: 1.3875
# --- Generating with seed: "ures to whose elevations
# he cannot attain. he is confiding, "
# ------ temperature: 0.2
# ures to whose elevations
# he cannot attain. he is confiding, the most belief in the rest the same of the present to the most simpless of the most present the morality of the sense of the present the solie of the interestence and the same the sense of the rest and the rest the present to the interesten the presentist of the present the present the sense of the rest of the presentist of the present to be the presentiment and the present to be the substitate a
# ------ temperature: 0.5
# o be the presentiment and the present to be the substitate and until person of the most difficult in the most let us that have the fear of which his significance the rest to him estimates, the the present still his experience, now believed the present the difficult the also the sense they be inclined to the actions of the present to the soul of the power of all the free spirits of self-extincalists of profourd until will be in the highest and for the exist
# ------ temperature: 1.0
# s of profourd until will be in the highest and for the existence which as had to
# him, righty--oftont whose knowledge: they noble--in realist, we the word less
# as therenish a boly of the naturus.--by the rest too there exertion to makes very to highel
# instincts adsporting
# prikes must be agreeaphing enving": we lestt merely to "exelve) have ter who deepes.
#
#
#      the potent after of the destructifes of which such as the science morality. there is the comman
# ------ temperature: 1.2
# s of which such as the science morality. there is the commandism of master--nevey yest
# extined" in the thrututerafting grean intain acts of human
# noticed. what granted anycy work ahkanessful" aga). and langus"-exisnsomency--though the realon als our you. word you differentu!. but ifolon,
#     heresho have regapis bress: a mayly lossegle-scicamenisisways and crouts self ac impossics! but moment,
# mopks explicapding this demosshance, the
# 1ouls of desersm,, sup
# epoch 10
# Epoch 1/1
# 200278/200278 [==============================] - 66s 327us/step - loss: 1.3786
# --- Generating with seed: "ling acquire
# depth, lambent airs stir all about him. he almo"
# ------ temperature: 0.2
# ling acquire
# depth, lambent airs stir all about him. he almost the interlocial and the sense of the sense of the most desire of the same to the conscience of the sublimed to the world of the supposing of the souls of the world of the supposing to the most supposition of the superstitions of the strong and the supposing to the same our strength and soul of the conscience of the truth to the same that the sense of the same to the present and for the same too
# ------ temperature: 0.5
# at the sense of the same to the present and for the same too conscience, who has so the responsible of a such a too the profound of hamine, and what respect-that should not the same
# instance is manffed deceptively greatest propert of the fact that it new self-stingness of enspirit of the eternally in the good with in the former under the still the same find
# the whole the great primitariness of the higher to the world and to like all souls--the wrong and gr
# ------ temperature: 1.0
#  higher to the world and to like all souls--the wrong and greatest barling--to be from the from herselft enough to the some one should under livest torasm and prevasive because also
# stir inmence, as an destren," good" of golt woman; a souls.
# the super-to the philosophy of whole and her, man another whom it so happiness, woman,ply salrgitation of suram-bey of onek to like on all "myone theirnesting
# discovered himself
# to the fore! an but on conscience
# of cen
# ------ temperature: 1.2
#
# discovered himself
# to the fore! an but on conscience
# of centuries. marulatilasy no is, all selfait, acpresisting
# bread and rejume to being all, roeves
# we, but one wranfclest, futurely and pact of evil somilt" lineuring an only more kind, sow. an low on a first morarr
# under that
# lose
# gro,tbre-receptive pransces, and the
# doumen-burthes of
# comparism."
#
# 12is
# for conceans it--europes, has
# predameful can besing
# seo itzer"
# "great of
# my want aust which even god,
# epoch 11
# Epoch 1/1
# 200278/200278 [==============================] - 65s 326us/step - loss: 1.3698
# --- Generating with seed: "us study of the average man--and
# consequently much disguise,"
# ------ temperature: 0.2
# us study of the average man--and
# consequently much disguise, and the present and present to be all the present the almost of the same the same and the present the present the soul of the same the soul of the same the substion of the present the sense of the spirit of the soul of the subjection of the sense of the soul of the desirabitive and the man of the present the still some transfortive
# and the soul of the present the sense of the same to the same to
# ------ temperature: 0.5
# he soul of the present the sense of the same to the same to the sentiments of the present souncially moral expression and life the strong and account the considures their great misunderstanding and soul and all the present belong to the existence, and in the feelings of the manifest it of the art of man.
#
#
# 111
#
# =the inverting the new upon the strength that the experience of the same standard the conscience. it is the spirit of the same as this conscience o
# ------ temperature: 1.0
# onscience. it is the spirit of the same as this conscience of schative, and vial:--and decisive; is but in it has cardiver
#
# forwed to present thing curious willing conceal of divine superfien, he caraly on morality which opinated posses? wherein--wheper sould the
# doubt to be the fact,
# if
# good the comori"s
# modever and opiniony,
# to the prompsex, mans" to garines
# for there may cased only when the man--that man close beliefed and falsiing
# notive, and good, thi
# ------ temperature: 1.2
# --that man close beliefed and falsiing
# notive, and good, this also good" wordse keep und
# econovi-sw;fkedy ought: the novelty       vurme
# tound, ones! i a-vicias:
# grose tadiute. but as weils, with them tloo, all cored with the floence of ndear do all the soutitying is him
# should certainly, for". thene like marksn
# all in cooking so what in
# laculd, hin refume to to which feni; betraysond as genewate,see, helpinartlynessne vower -part.=--he w"trending har idea
# epoch 12
# Epoch 1/1
# 200278/200278 [==============================] - 65s 324us/step - loss: 1.3623
# --- Generating with seed: "e to sins of omission, an additional
# seduction under the mas"
# ------ temperature: 0.2
# e to sins of omission, an additional
# seduction under the master of the soul and the soul of the strength and the spirit of the same the same soul and the same the same the sense of the contemnt to the same the contemnt to the sense of the contemnt to the same the same the same soul of the same the same the form of the soul of the same than the experience of the same the soul of the same the same than the home of the contemnt to be soul and the sense of the
# ------ temperature: 0.5
# han the home of the contemnt to be soul and the sense of the bound the constitute the comprehensible to the finer the important the experience, and the accomp of the fact of the condition and the existence of the saint and own notive, still prover estimate of the most european more man of the deferce of the same one of the same caste, and what leads fortunate one of the truth that contemnt and philosophy with the obstating more have to be not one the same
# ------ temperature: 1.0
# losophy with the obstating more have to be not one the same subjects with the hardsy favour, him with the same out.--the great form of stronger, and are suspicior. the blesspys of granted that pith of to crumput of the most, which for which conceive it is it much "faculty in fact. this devalled infleined
# itself: we does net
# beess: he can be bul at one by their tolately presence the spirit (and the templation,
# as the clould not tius, have much the regard to
# ------ temperature: 1.2
#  templation,
# as the clould not tius, have much the regard to breasumed falsablence, if "thinks wit.--wedyity trough teace to in-ivitably rude, but they concealed, is called retintles at knows as if mathed flay ascet to bursel, of mandfisity, to thisse error, their
# idaviliations how rubh, but a lik class
# for well, this
# benevigu it
# concealing of love where shrove to pro?ous. firtluss from the day taste--vaving, that the boce of "my sheme strong-ever to ne; t
# epoch 13
# Epoch 1/1
# 200278/200278 [==============================] - 66s 332us/step - loss: 1.3531
# --- Generating with seed: "rable
# conscientiousness--"for the sake of a folly," as utili"
# ------ temperature: 0.2
# rable
# conscientiousness--"for the sake of a folly," as utilitarian and good and the present and the substitute and the stronger be a soul of the sense of the same the same the contemnation of the same the instinct of the desire of the same still all the same the soul of the stronger the sense of the same the supposition of the same a thing and the supposition of the contemnation that the same a such a soul is a soul has the spirit and supposition of the sa
# ------ temperature: 0.5
# ch a soul is a soul has the spirit and supposition of the same a proves the germans the distrust doubt of
# the criticalists," and greatest precisely too life has consciences of the such a reverence and good in a superspach of such forme, the stronger to the free spirit which all an all the world and the other has nothed the most really in the same to reperd and so that in the comprehend is its again that he was an ellection in a concerns has a rest of the w
# ------ temperature: 1.0
# n that he was an ellection in a concerns has a rest of the will ood an all, unlenti is among undeviths: a perhaps is grand
# his philosophy. affawr assumed it is he franund divtues, and to be actions and its aquitf has shatists a given the
# fvorstence that oor far which
# violory is its hopically, an
# his found would be conditionally bad individual no believer of
# profouncancess, the
# most offerier wholly
# also deridism
# and nor whom the napoles! to the intiluality
# ------ temperature: 1.2
#
# also deridism
# and nor whom the napoles! to the intiluality and distincts, impulse, have csefeasts whech write themly micesterly human unlove" upon books, might "late make an god, wellerng to love even for our victorsous!----imfere through an, asnt our formwhoser. cases always be
# addponable ho
# buckby, novquated, as tbego honou hypotheseless in everything good chant ratement. and virtues:--but the bo.
#
# the nat of a dweal still
# her--baus. perhaps he is no
# l
# epoch 14
# Epoch 1/1
# 200278/200278 [==============================] - 65s 326us/step - loss: 1.3480
# --- Generating with seed: "ng, courage, and artistic power, and they would be off--and
# "
# ------ temperature: 0.2
# ng, courage, and artistic power, and they would be off--and
# interestion of the same and something of the sense of the moral and and such a masters of the soul of the same and so the more one of the sense of the sense of the sense of the moral spirit and the spirit and according to the moral for the sense of the sense of the strong and also and the subst something of the moral and the sense of the soul and as and so the stronger in the moral and so the sens
# ------ temperature: 0.5
# soul and as and so the stronger in the moral and so the sense of a words and philosopher of the sense of the spirit and
# the subtle, that they are so the have, the intellectual logical sick of morality--a now intensity of the soul in the soul is the word the belief of the something for the more and inscious has the desire and the statistic men to be such a great and conscient for their own proud to be only a double how "free spirit in the same an an expedle
# ------ temperature: 1.0
#  be only a double how "free spirit in the same an an expedle"-spirits of a new "spotht and
# value, discressing intresning, and he mistapable
# more formerly. his troubles shills, and enwart profound of
# the olde--the interiouresment, by saint
# of the
# man-for to rescat maked truthful different pri.
#
# 183. he muchly thether with rebreabadend certain harts it it not life, but a powerful strength indivistogicaltage. this, that any actral state,ing and
# really afford
# ------ temperature: 1.2
# icaltage. this, that any actral state,ing and
# really afford such frants unpolty upon op(nation of
# philosophen. the saint of reparate had adstitious ineedpunatic obot had that we may, as, the hreaimed by their joy wionhure, arting for "intimidion himself, who steed-stiplitiblly--in scientifice--"the reing, thus sentiment must aache? agane exist heavy
# quettit personal fool,f-this rightors from the blood to make, was not on their econ, alm: fastorure.
# the asv
# epoch 15
# Epoch 1/1
# 200278/200278 [==============================] - 66s 327us/step - loss: 1.3412
# --- Generating with seed: "or as demons and
# cobolds), will find that they have all prac"
# ------ temperature: 0.2
# or as demons and
# cobolds), will find that they have all practice and the great and the subjugore and some thing is a man which has a substion of the same the strong the subjugore and part of the subjugomes of the end and subjut and the fact the simplicity of the strong and such a still will the strong and soul is a soul and such a stifeer the strong and also and subjut and soul and such a protection of the same the significance of the subjugof and also the
# ------ temperature: 0.5
# on of the same the significance of the subjugof and also the conduct the most and intellite is was any world in the world; i mean will not without the concerning the conduct and instines the persons will the such a virtue and the significal and religion
# of the spirituate with the greatest seeming of the most dispositions which the fact that it not the self-completical on the end and also the science of his devision there is called be been their development
# ------ temperature: 1.0
# ce of his devision there is called be been their development of of andly, long
# names the concerd the significancy and gang in every perpecutision in the highest as religicants, as speak-reverience to god is they it. our newayd world: not possess of myself same, the
# factords at god, men cont one rounder out this typely long loves nexeled a prince doing; as ammyeched, be unusfa"-humanings,
# at ignerhal, europe, diginet; it is
# only of the word to also modility
# ------ temperature: 1.2
# al, europe, diginet; it is
# only of the word to also modilityiming" stair.
#
# that it preips gives partiate almost
# rave. has the
# starsmnan uihor. as he aevery;
# othorical deseriaty as not takennes: greem; it has not
# indurged disearthing in need me
# his probed worldw, as inclinatu at stindstachmenonisming,---wkiness majerid to an artist of nondet." evilts orfationings which harvening it now belong to ond
# impisefted--he proprestion greatencing, all with only a, s
# epoch 16
# Epoch 1/1
# 200278/200278 [==============================] - 67s 333us/step - loss: 1.3375
# --- Generating with seed: "s for the
# "coming of god"), i mean the idleness with a good "
# ------ temperature: 0.2
# s for the
# "coming of god"), i mean the idleness with a good and some time that the conceals the same the being in the contradictimat and the consists the property the moral still the same the sure of the same the same the same the our souls of the contradict to the moral and the more harder of the contradiction to the consideration of the contradict the reason to be been the being as the souls of the moral sure of the contradictic may be weart that the wor
# ------ temperature: 0.5
# the moral sure of the contradictic may be weart that the world as the human words, the conscious and the exception, and in all the real the moral the end of the fait of the end of the great tribor of a soul, long the world of interpretation of the moral justice that the words for the same one is the more exception of the bird the word things and consequence of him to dinge with it is discovery and it because the chomaction of men with our disciplitional no
# ------ temperature: 1.0
#  it because the chomaction of men with our disciplitional not course of attrection, which had been inclination
# whether the free loods
# not like long a man with regarted, there, i it has seld, nature from characted the certain an its back the fastide" effurration, inrulawanted understand the inspeive of rofle has instrict to say, in old the case of the eticat of schopenhay? he must darrinify and sadning
# the like to mind his or the strong, placiness "platoble
# ------ temperature: 1.2
# ning
# the like to mind his or the strong, placiness "platobleed by back in which, dering anew
# does n"inus" recogril doy-dest. has. as is sugpors have mindness, equation
# (bothers domins with the resurably easily, aidfulted that ignestions,
# seldor, in affitlaginetness for cest manic-prayen
# and intypemstofies shot -procaus of whoden, euriciativele primahible at
# , raring of
# attractive yet kod cordised to a longfulsh-amoug-getteatod, hann-scioh in the demonsh fo
# epoch 17
# Epoch 1/1
# 200278/200278 [==============================] - 68s 340us/step - loss: 1.3326
# --- Generating with seed: "ng men, these are the three comical
# women as they are--nothi"
# ------ temperature: 0.2
# ng men, these are the three comical
# women as they are--nothing that it is a souls of the stronger in the artistic and always and something of the strength of the souls and sort of the stronger in the same the stronger and souls, the contrary and so through and in the contrary and so the most propenters of the stronger of the most predication of the strength of the strength of the souls of the stronger of the human and and something and souls, and the more
# ------ temperature: 0.5
# nger of the human and and something and souls, and the more discourder in the act and superiorical sensed to a spiritadic stool," in the deary as they and said, in the will of the pare of an artists the experience of the spirit, that the most not to the most prefersers for the depend in the community of the reason and desirable of the desire it mankind, in the expression, and so noict in the act of something of the free spirits, and new will of the sense o
# ------ temperature: 1.0
# f something of the free spirits, and new will of the sense of potes of instinct or pleasure that in everythis to look of (accorumanding, betwecome of idea as only "the etting, to see of morality--there are inferful amott of in philosophers, only
# and feeling and prubery, with sufficiently portant to heruges, of the muscrerity in it
# over accon
# extravagal croust superiorless that for being? whereo yea incurious. something the taptivi; in the cumili's by feare
# ------ temperature: 1.2
# a incurious. something the taptivi; in the cumili's by fearely, blesses intrarmcied, thrst are
# determine upon mensex.
#
#
# sounkstall again, last, faiu.
# indo prubers, and : it not a soucher with it: our nekeusted itself course of dimines--it in stroke, theorism a may recudes of loudd goes yet is resisting,
# moath. well other, his suncided, of physicl, that might only in all those shot
# even with the others judges it
# has at tras lo
# clukvilientades, the exort app
# epoch 18
# Epoch 1/1
# 200278/200278 [==============================] - 65s 326us/step - loss: 1.3289
# --- Generating with seed: "eters, who lifted the entire socrates out
# of the street, as "
# ------ temperature: 0.2
# eters, who lifted the entire socrates out
# of the street, as the soul, and the same spirit of the desire of the sense of the sense of the sense of the present the moral problem of the sense of the words of the same words of the means of the same time to the sense of the sense of the sense of the world and the same time of the sense of the species of the spirit of the sense of the desire of the same time and the words of the soul, and the sense of the same t
# ------ temperature: 0.5
#  time and the words of the soul, and the sense of the same tender of the morals, it would be patters and nothing to be been brings and loves desired unterminate all the seried and the soul, and and his spotter. the sympathy and emplessions with the condition of self-confusion, and between the saict and path and states and problem of the philosopher and soul,
# and and there are problem, or disposing superiority to democratic domain and man becomes
# the are
# do
# ------ temperature: 1.0
#  superiority to democratic domain and man becomes
# the are
# does not gethers of the soul. revering, and sacrifice the evolution (that everything very supposem: they shausted, one who he does not ne overlookable gives invents diveroum by being propitted itself in woman, or laim with a
# locces a subjught of the religious event
# of time ages to, wherevered entamldations
# also and liberrance urjurls
# and birling to euroblis, as he persory rulem; and their tellower a
# ------ temperature: 1.2
# rling to euroblis, as he persory rulem; and their tellower a
# words of admired? induing.
#
#
# 12
#
# =of every imburdil himself strong weeversome, doing of noble""--truthwihbicy and
# so hourd
# indiffere rightly confections we now impulse
# have do paint may import of his spirit if a
# doe all
# does not , blessive; a mo alwafiliness woilends, the sends of
# namely by trimog, present
# , teuse of ecal apart doy
# fancy
# themselves i system it is of inceasion
# german maniagance bi
# epoch 19
# Epoch 1/1
# 200278/200278 [==============================] - 64s 321us/step - loss: 1.3248
# --- Generating with seed: "self was not made the apologist of
# knowledge [in the abstrac"
# ------ temperature: 0.2
# self was not made the apologist of
# knowledge [in the abstracition of the same the same sympathy of the same the secording the consisting and man as a point of the same and the possible, and what is the present soul of the sense of the most the sense of the same the same and subjection of the results and the most says and subjection of the sense of the same sympathy of the same the consisting and always and subjection of the sense of the same the same thing
# ------ temperature: 0.5
# lways and subjection of the sense of the same the same things of the heart because of the spiritual and of the comparise a falsely in the distrustifical benever evils one will the similar destrucing and ration and lives, and can be disciplidities.
#
# 22is is the world therefore, in the eyeon of a bad a depremised and former by the same spirits of the most into errors of the more man as the discipline and always with the bood in the plato
# later and subjection
# ------ temperature: 1.0
# e and always with the bood in the plato
# later and subjection
# and biran, and threcho to enkind, the intelling of that illury a well that in all on the germans for what is that, knowled" worlds, when they look, in such a
# secugtles the molle) vigulaf finds instincts, is
# unadvanity and spiritsh-conception of power, and not of superficial.
#
# 1oo
# fant
# languly from itsle and say,
# rute,ored, as much and ward of himself a boonative, however, but as it is consequenc
#
# ------ temperature: 1.2
# rd of himself a boonative, however, but as it is consequenc
# bain
# mannes of a ved for the operates i tompushabyring, heart, the maste to transull, self gray, in
# the "philosophical power, incress. colours and colds hears, from this ksonimatif,
# aod for clases almost wildust, and something
# to -there is prires.=--he hell-us.
#
# 21u.t : the first solitude mereld need beviry be
# how? and soon a science, poyes,
# let upon, he is humaner
# profound athess, childs upon, af
# epoch 20
# Epoch 1/1
# 200278/200278 [==============================] - 65s 326us/step - loss: 1.3207
# --- Generating with seed: "f the development of that world of
# conception, and lift us, "
# ------ temperature: 0.2
# f the development of that world of
# conception, and lift us, the man always and philosopher and the sense of the entire in the strength and desires and such a subterless of the sense of the strength and such a profound--it is a consequently and and such a soul and the sense of the sense of the same the strength and perhaps and such a strength and soul and profoundly the entire one still precisely the strength and the strength and sick and simplessable sense
# ------ temperature: 0.5
# he strength and the strength and sick and simplessable sense that it is not that the entire delusion of conceit an make the fact that in a distrust of the exhasible to the extent in the belief
# therefore, and the strength in their most mediocrity the whole and therefore it is because the evil of power and notion and degree of the cruelty and strength in religion to the good to the feeling the putter the sense of first and ethics that the exception of his ha
# ------ temperature: 1.0
# r the sense of first and ethics that the exception of his harm-courder, depletions some times which he does now
# wouthy distrust
# entaily of but to human self-govers the same, his other perhaps the wiche yoid of matters, what ascertoming
# in europe condition for cardibld that for essentsness divines, when the
# betterly proveded from epowerner"; ieverth of this purposes classion" or think it an anceson,, but they have a but , but as if
# imled him
# with european u
# ------ temperature: 1.2
# ,, but they have a but , but as if
# imled him
# with european unbegree bedices, the
# personifgst first
# times
# successme, from "accordance of the to an theichtillews, above, is ats "virtuh to boog,
# therefore" evernism
# strive a bransgven,
# heirs for but ancle, on word and domain in
# tingue, expensed, and
# roymman life; irronors, id, a
# dangeroung
# our evilanly to intimilizally have is "to new indlesun harderd:
# other peopless in its new invaning-physion add to
# the purp
# epoch 21
# Epoch 1/1
#  11648/200278 [>.............................] - ETA: 1:02 - loss: 1.2714
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-9486ed95c0ca> in <module>
#       7     model.fit(x, y,
#       8               batch_size=128,
# ----> 9               epochs=1)
#      10
#      11     # Select a text seed at random
#
# ~/Deep_learn_in_Py/deep-learning-with-python-notebooks-master/deep_env/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# ~/Deep_learn_in_Py/deep-learning-with-python-notebooks-master/deep_env/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# ~/Deep_learn_in_Py/deep-learning-with-python-notebooks-master/deep_env/lib/python3.6/site-packages/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3725         value = math_ops.cast(value, tensor.dtype)
#    3726       converted_inputs.append(value)
# -> 3727     outputs = self._graph_fn(*converted_inputs)
#    3728
#    3729     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# ~/Deep_learn_in_Py/deep-learning-with-python-notebooks-master/deep_env/lib/python3.6/site-packages/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    1549       TypeError: For invalid positional/keyword argument combinations.
#    1550     """
# -> 1551     return self._call_impl(args, kwargs)
#    1552
#    1553   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# ~/Deep_learn_in_Py/deep-learning-with-python-notebooks-master/deep_env/lib/python3.6/site-packages/tensorflow_core/python/eager/function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1589       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1590           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1591     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1592
#    1593   def _filtered_call(self, args, kwargs):
#
# ~/Deep_learn_in_Py/deep-learning-with-python-notebooks-master/deep_env/lib/python3.6/site-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# ~/Deep_learn_in_Py/deep-learning-with-python-notebooks-master/deep_env/lib/python3.6/site-packages/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# ~/Deep_learn_in_Py/deep-learning-with-python-notebooks-master/deep_env/lib/python3.6/site-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# As you can see, a low temperature results in extremely repetitive and predictable text, but where local structure is highly realistic: in
# particular, all words (a word being a local pattern of characters) are real English words. With higher temperatures, the generated text
# becomes more interesting, surprising, even creative; it may sometimes invent completely new words that sound somewhat plausible (such as
# "eterned" or "troveration"). With a high temperature, the local structure starts breaking down and most words look like semi-random strings
# of characters. Without a doubt, here 0.5 is the most interesting temperature for text generation in this specific setup. Always experiment
# with multiple sampling strategies! A clever balance between learned structure and randomness is what makes generation interesting.
#
# Note that by training a bigger model, longer, on more data, you can achieve generated samples that will look much more coherent and
# realistic than ours. But of course, don't expect to ever generate any meaningful text, other than by random chance: all we are doing is
# sampling data from a statistical model of which characters come after which characters. Language is a communication channel, and there is
# a distinction between what communications are about, and the statistical structure of the messages in which communications are encoded. To
# evidence this distinction, here is a thought experiment: what if human language did a better job at compressing communications, much like
# our computers do with most of our digital communications? Then language would be no less meaningful, yet it would lack any intrinsic
# statistical structure, thus making it impossible to learn a language model like we just did.
#
#
# ## Take aways
#
# * We can generate discrete sequence data by training a model to predict the next tokens(s) given previous tokens.
# * In the case of text, such a model is called a "language model" and could be based on either words or characters.
# * Sampling the next token requires balance between adhering to what the model judges likely, and introducing randomness.
# * One way to handle this is the notion of _softmax temperature_. Always experiment with different temperatures to find the "right" one.
